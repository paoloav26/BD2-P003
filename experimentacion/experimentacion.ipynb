# %%
import matplotlib.pyplot as plt

# %%
from unicodedata import name


secuencial=[0.00185037,0.00560069,0.01148677,0.02149701,0.01558828,0.03169847,0.16779065,0.10855675]

plt.title('Cantida de datos Vs Tiempo de ejecución')
plt.xlabel('Cantidad de datos')
plt.ylabel('Segundos de ejecución')

valores=[100,200,400,800,1600,3200,6400,12800]
secuencial=[0.00185037,0.00560069,0.01148677,0.02149701,0.01558828,0.03169847,0.16779065,0.10855675]
rtree=[0.01941872,0.02719474,0.04768586,0.02569628,0.02265048,0.04271317,0.09990478,0.09469271]
highd=[0.00194693,0.00145698,0.01214409,0.00153877,0.00298381,0.00888276,0.03889823,0.02192521]

plt.plot(valores, secuencial, '-o')
plt.plot(valores, rtree, '-o')
plt.plot(valores, highd, '-o')

plt.legend(['Knn-Secuencial','Knn-Rtree','Knn-HighD'])

plt.show()

# %%
N = 100	º   0.00185037s	0.01941872s	0.00194693s
N = 200	º   0.00560069s	0.02719474s	0.00145698s
N = 400	º   0.01148677s	0.04768586s	0.01214409s
N = 800	º   0.02149701s	0.02569628s	0.00153877s
N = 1600	0.01558828s	0.02265048s	0.00298381s
N = 3200	0.03169847s	0.04271317s	0.00888276s
N = 6400	0.16779065s	0.09990478s	0.03889823s
N = 12800	0.10855675s	0.09469271s	0.02192521s
